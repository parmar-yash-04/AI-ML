# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.read_csv(r'C:\Users\ASUS\Downloads\validation_ordinal_enco.csv')
df.head()
# Out:
#    Age  Grade  Gender      Race  SES_Quartile ParentalEducation SchoolType  \
# 0   14      9  Female  Hispanic             3       SomeCollege     Public
# 1   17     12  Female     White             4       SomeCollege     Public
# 2   17     12  Female     Other             2                HS     Public
# 3   15     10    Male     White             4       SomeCollege     Public
# 4   18     12    Male     Black             3                HS     Public
#
#      Locale  TestScore_Math  TestScore_Reading  ...       GPA  AttendanceRate  \
# 0      City       90.186244          88.390291  ...  3.509322        0.964022
# 1     Rural       73.356297          73.471428  ...  3.118458        0.882988
# 2  Suburban       73.970459          76.085029  ...  3.640436        0.864401
# 3  Suburban       64.500290          63.858629  ...  2.990611        0.887791
# 4      City       84.546267          88.502675  ...  3.546262        0.933201
#
# ...

# %%
ndf = df.iloc[:,:7]

# %%
ndf.head()
# Out:
#    Age  Grade  Gender      Race  SES_Quartile ParentalEducation SchoolType
# 0   14      9  Female  Hispanic             3       SomeCollege     Public
# 1   17     12  Female     White             4       SomeCollege     Public
# 2   17     12  Female     Other             2                HS     Public
# 3   15     10    Male     White             4       SomeCollege     Public
# 4   18     12    Male     Black             3                HS     Public

# %%
ndf.shape
# Out:
# (999229, 7)

# %%
df.isnull().sum()
# Out:
# Age                  0
# Grade                0
# Gender               0
# Race                 0
# SES_Quartile         0
# ParentalEducation    0
# SchoolType           0
# Locale               0
# TestScore_Math       0
# TestScore_Reading    0
# TestScore_Science    0
# GPA                  0
# AttendanceRate       0
# StudyHours           0
# InternetAccess       0
# Extracurricular      0
# PartTimeJob          0
# ParentSupport        0
# Romantic             0
# FreeTime             0
# GoOut                0
# dtype: int64

# %%
ndf.head()
# Out:
#    Age  Grade  Gender      Race  SES_Quartile ParentalEducation SchoolType
# 0   14      9  Female  Hispanic             3       SomeCollege     Public
# 1   17     12  Female     White             4       SomeCollege     Public
# 2   17     12  Female     Other             2                HS     Public
# 3   15     10    Male     White             4       SomeCollege     Public
# 4   18     12    Male     Black             3                HS     Public

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['SchoolType']),df['SchoolType'], test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (799383, 20)

# %%
print("Unique Values:", df['ParentalEducation'].unique()[:10])
# Out:
# Unique Values: ['SomeCollege' 'HS' '<HS' 'Bachelors+']

# %%
ordinal_cols = ['Grade', 'SES_Quartile','ParentalEducation']
ordinal_categories = [['9', '10', '11', '12'],
                      ['1', '2', '3', '4'],
                      ['<HS','HS','SomeCollege','Bachelors+']                     
                     ]

nominal_cols = ['Gender', 'Race']
numeric_cols = ['Age']

# %%
preprocessor = ColumnTransformer(transformers=[
    ('ord', OrdinalEncoder(categories=ordinal_categories), ordinal_cols),
    ('nom', OneHotEncoder(drop='first'), nominal_cols),
    ('num', 'passthrough', numeric_cols)
])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('ord',
#                                  OrdinalEncoder(categories=[['9', '10', '11',
#                                                              '12'],
#                                                             ['1', '2', '3',
#                                                              '4'],
#                                                             ['<HS', 'HS',
#                                                              'SomeCollege',
#                                                              'Bachelors+']]),
#                                  ['Grade', 'SES_Quartile',
#                                   'ParentalEducation']),
#                                 ('nom', OneHotEncoder(drop='first'),
#                                  ['Gender', 'Race', 'SchoolType']),
#                                 ('num', 'passthrough', ['Age'])])

# %%
preprocessor.fit_transform(X_train)
# Out:
# array([[ 0.,  0.,  1., ...,  0.,  1., 14.],
#        [ 3.,  1.,  0., ...,  0.,  1., 18.],
#        [ 1.,  0.,  2., ...,  0.,  0., 15.],
#        ...,
#        [ 3.,  0.,  0., ...,  0.,  0., 17.],
#        [ 1.,  0.,  1., ...,  0.,  0., 15.],
#        [ 0.,  3.,  3., ...,  0.,  0., 14.]])
